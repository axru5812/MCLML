# %%
from datareader import MclyaReader
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
reader = MclyaReader()
v, fl = reader.get_single_spectrum(9,9,0,6)
# Out:
# V exp:  500.0
# NHI:  20.8
# b:  10.0
# tau:  3.0
# EW [KMS]  34524.89573650744
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
win = np.where((v<2500)&(v>-2500))
x, y = reader._smooth(v, fl, R=8000)
plt.plot(x[win], y[win])
# Out:
# <img src="data:image/png;base64,..." width="640">
